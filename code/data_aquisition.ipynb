# %% [markdown]
# ## Imports and Dependencies
#
# In this section, we import the necessary libraries that will be used throughout the notebook for data processing, requests handling, and timing operations.
#
# ### Libraries Overview
#
# - **`pandas`**: A powerful data manipulation library used for data analysis and manipulation.
# - **`requests`**: A Python library used for sending HTTP requests to interact with external APIs.
# - **`time`**: A module that provides time-related functions, used to handle delays or capture timestamps.
# - **`json`**: A module for working with JSON data, which allows easy parsing and manipulation of JSON files.

# %%
#Python Standard Libraries
import time
import json

# You will need to install these with pip/pip3 if you do not already have it
import pandas as pd
import requests

# %% [markdown]
# ## Data Loading
#
# In this section, we load the datasets that will be used for further analysis. We are working with two datasets:
#
# 1. **Politicians Data**: This dataset contains information about politicians and their associated Wikipedia articles.
# 2. **Population Data**: This dataset includes the population of different countries and regions as of August 2024.

# %%
# Import the dataset containing politicians' information
politicians_df = pd.read_csv('../data/politicians_by_country_AUG.2024.csv')

# Import the dataset containing population statistics by country
population_df = pd.read_csv('../data/population_by_country_AUG.2024.csv')

# Display the first few records of the politicians dataset to verify it loaded correctly
print(politicians_df.head())

# Display the count of non-null entries in each column of the politicians dataset
politicians_df.count()

# Display the first few records of the population dataset to verify it loaded correctly
print(population_df.head())

# Display the count of non-null entries in each column of the population dataset
population_df.count()
# Out:
#                    name                                                url  \
# 0        Majah Ha Adrif       https://en.wikipedia.org/wiki/Majah_Ha_Adrif
# 1     Haroon al-Afghani    https://en.wikipedia.org/wiki/Haroon_al-Afghani
# 2           Tayyab Agha          https://en.wikipedia.org/wiki/Tayyab_Agha
# 3  Khadija Zahra Ahmadi  https://en.wikipedia.org/wiki/Khadija_Zahra_Ah...
# 4        Aziza Ahmadyar       https://en.wikipedia.org/wiki/Aziza_Ahmadyar
#
#        country
# 0  Afghanistan
# 1  Afghanistan
# 2  Afghanistan
# 3  Afghanistan
# 4  Afghanistan
#          Geography  Population
# 0            WORLD      8009.0
# 1           AFRICA      1453.0
# 2  NORTHERN AFRICA       256.0
# 3          Algeria        46.8
# 4            Egypt       105.2
# Geography     233
# Population    233
# dtype: int64

# %% [markdown]
# ## Duplicate Detection
#
# In this section, we identify any potential duplicates in the dataset of politicians. We will perform checks based on two different criteria:
#
# 1. **All Columns**: Checking for exact duplicates across all columns.
# 2. **Name + URL**: Checking for duplicates where only the name or URL is repeated.

# %%
# Identify and count duplicates considering all columns
duplicate_politicians_all = politicians_df[politicians_df.duplicated()]
print(len(duplicate_politicians_all))

# Identify and count duplicates based only on the 'name' column
duplicate_politicians_name = politicians_df[politicians_df.duplicated(subset=['name'])]

# Identify and count duplicates based only on the 'url' column
duplicate_politicians_url = politicians_df[politicians_df.duplicated(subset=['url'])]

# Display the number of duplicated entries found for name and URL
print(len(duplicate_politicians_name))
print(len(duplicate_politicians_url))

# Explanation: Duplicate names and URLs suggest that the only distinguishing feature is the country field.
# Out:
# 0
# 44
# 44

# %% [markdown]
# ## Data Cleaning: Removing Zero Population Rows
#
# In this step, we clean the population dataset by removing rows where the population value is zero. This ensures that we are working with valid data and that any countries or regions with a population of zero are excluded from further analysis.

# %%
# Remove rows where the population value is 0
# This ensures that we only consider countries or regions with a valid population for analysis
population_df = population_df[population_df['Population'] > 0]

# After filtering, only countries/regions with a population greater than 0 remain in the DataFrame

# %% [markdown]
# ## Checking for Duplicates in Population Data
#
# To ensure data accuracy, it's crucial to check for duplicates within the population dataset. We will check for duplicates across all columns as well as duplicates specifically within the `Geography` column. This step helps identify and remove any redundant entries, ensuring the uniqueness and correctness of the data for analysis.

# %%
# Check for duplicates across all columns in the population DataFrame
# This will identify any rows that are exact duplicates (i.e., all column values are the same)
duplicate_population_all = population_df[population_df.duplicated()]
print(f"Number of duplicate rows across all columns: {len(duplicate_population_all)}")

# Check for duplicates based only on the 'Geography' column
# This will check if any countries or regions appear more than once in the dataset based on their 'Geography'
duplicate_population_geo = population_df[population_df.duplicated(subset=['Geography'])]
print(f"Number of duplicate entries based on 'Geography': {len(duplicate_population_geo)}")
# Out:
# Number of duplicate rows across all columns: 0
# Number of duplicate entries based on 'Geography': 0

# %% [markdown]
# ## Handling Politicians Appearing in Multiple Countries
#
# Some politicians appear in the dataset associated with multiple countries. This could be due to their nationalities or because they have served in more than one country. Based on the information retrieved from the Wikipedia API, we have identified 44 politicians who appear in two or more countries.
#
# Since it makes sense for these politicians to be part of all the countries they are associated with, we will retain them in the dataset for each country. However, for record-keeping purposes, we will create and store a separate file containing these duplicates.

# %%
# 44 politicians appear in multiple countries (2 or more). This has been determined (based on the Wikipedia API)
# due to either their nationalities or the fact that they have served in multiple countries.
# It makes sense to include them as part of all the countries their names appear in.

# We create a combined DataFrame of duplicate politicians, 
# considering those with the same name and same URL (i.e., served in different countries).
combined_duplicates = pd.concat([duplicate_politicians_name, duplicate_politicians_url]).drop_duplicates()

# Save the combined duplicate entries for future reference or analysis.
# This will store the list of politicians who appear in multiple countries into a CSV file.
combined_duplicates.to_csv('../data/duplicate_politicians.csv', index=False)

# %% [markdown]
# ## Checking for Missing Values
#
# Before proceeding with the analysis, it is important to check for any missing values in the dataset. Missing values can affect the accuracy of the analysis, and identifying them allows us to take appropriate action, such as filling or removing them.

# %%
# Check for missing values in each column of the politicians dataset
# This will display the number of missing (null) values for each column in the DataFrame
missing_values_politicians = politicians_df.isnull().sum()
print("Missing values in politicians dataset:")
print(missing_values_politicians)

# Check for missing values in each column of the population dataset
# This will display the count of missing values per column, helping to identify any data quality issues
missing_values_population = population_df.isnull().sum()
print("\nMissing values in population dataset:")
print(missing_values_population)
# Out:
# Missing values in politicians dataset:
# name       0
# url        0
# country    0
# dtype: int64
#
# Missing values in population dataset:
# Geography     0
# Population    0
# dtype: int64

# %% [markdown]
# ## Constants and API Request Setup
#
# In order to fetch revision IDs and other information for Wikipedia articles, we set up the required constants, headers, and functions to interact with the Wikipedia API. These parameters will allow us to efficiently query the API while respecting the API's rate limits.
#
# ### API Constants
#
# The following constants have been defined for the API requests:
# - **API_ENWIKIPEDIA_ENDPOINT**: The base URL for Wikipedia's API.
# - **API_HEADER_AGENT**: The HTTP header for the user-agent string, identifying the requester.
# - **API_LATENCY_ASSUMED**: Assumed latency (in seconds) for API requests (roughly 2ms).
# - **API_THROTTLE_WAIT**: The calculated wait time to ensure we don’t exceed the API rate limit (100 requests per second).
# - **REQUEST_HEADERS**: Headers used in the API request, including the user-agent information that specifies the course and university details.
#
# ### Request Parameters Template
#
# We have created a template for querying the Wikipedia API for page information:
# - **PAGEINFO_PARAMS_TEMPLATE**: A dictionary that defines the basic structure of the request, including:
#   - **action**: Specifies the action to be performed, in this case, querying for information.
#   - **format**: The format of the response, set to `json`.
#   - **titles**: Placeholder for the article title.
#   - **prop**: Property to retrieve, in this case, basic info about the page.
#   - **inprop**: Additional properties to include, such as the URL and talk page ID.

# %%
# Constants

# Wikipedia API endpoint to fetch page information
API_ENWIKIPEDIA_ENDPOINT = "https://en.wikipedia.org/w/api.php"

# Header for the API request, which includes the User-Agent for proper identification
API_HEADER_AGENT = 'User-Agent'

# Assumed network latency for the API requests (in seconds)
API_LATENCY_ASSUMED = 0.002  # Assuming roughly 2ms latency on the API and network

# API throttle limit to prevent overloading the server (100 requests per second max)
API_THROTTLE_WAIT = (1.0 / 100.0) - API_LATENCY_ASSUMED  # Adjusting for latency

# Request headers used in each API request (User-Agent identifies the request source)
REQUEST_HEADERS = {
    'User-Agent': '<trips@uw.edu>, University of Washington, MSDS DATA 512 - AUTUMN 2024'
}

# Template for requesting page info from Wikipedia API (this template will be copied and updated for each request)
PAGEINFO_PARAMS_TEMPLATE = {
    "action": "query",        # The API action (query)
    "format": "json",         # The format for the response (JSON)
    "titles": "",             # Placeholder for the article title (filled in dynamically)
    "prop": "info",           # Retrieve basic info about the page
    "inprop": "url|talkid"    # Include the URL and the talk page ID in the response
}

# Function to request page info and retrieve revision ID for a specific article
def request_pageinfo_per_article(article_title):
    # Make a copy of the template and update the title field with the given article title
    request_template = PAGEINFO_PARAMS_TEMPLATE.copy()
    request_template['titles'] = article_title

    # Add a small wait to respect the API rate limit and avoid overloading the server
    if API_THROTTLE_WAIT > 0.0:
        time.sleep(API_THROTTLE_WAIT)  # Sleep for the calculated throttle time

    try:
        # Send a GET request to the Wikipedia API with the request template and headers
        response = requests.get(API_ENWIKIPEDIA_ENDPOINT, headers=REQUEST_HEADERS, params=request_template)
        # Parse the JSON response
        json_response = response.json()
        
        # Extract the 'pages' section of the JSON response to get page info
        pages = json_response["query"]["pages"]
        for page_id, page_info in pages.items():
            # Extract the last revision ID for the article
            revision_id = page_info.get("lastrevid", None)
            if revision_id:
                return revision_id  # Return the revision ID if available
            else:
                return None  # Return None if no revision ID found
    except Exception as e:
        # Handle any errors that occur during the API request
        print(f"Error fetching page info for {article_title}: {e}")
        return None  # Return None in case of error

# %% [markdown]
# ## ORES API Setup
#
# In this section, we configure and define functions to interact with the **Objective Revision Evaluation Service (ORES)** provided by Wikipedia. ORES helps us to retrieve quality predictions for Wikipedia articles based on their revision IDs.
#
# ### ORES API Constants
#
# We define the constants required for making requests to the ORES API:
# - **ORES_ENDPOINT**: The base URL for querying ORES.
# - **ORES_MODEL**: The machine learning model used to predict the quality of Wikipedia articles. For this project, we are using the `wp10` model, which categorizes articles into various quality classes (e.g., Stub, Start, B, GA, FA).
#
# ### Function to Retrieve ORES Quality Prediction
#
# The function `get_ores_quality_prediction(article_title, revision_id)` takes an article title and its revision ID as input and queries the ORES API to get the quality prediction for the article. It processes the API response and returns the predicted quality score.

# %%
# ORES API Constants

# Endpoint for querying article quality scores using the ORES API
ORES_ENDPOINT = "https://ores.wikimedia.org/v3/scores/enwiki/"

# ORES model used for quality prediction; 'wp10' is the model used to classify article quality
ORES_MODEL = "wp10"

# Function to request article quality prediction from the ORES API
def get_ores_quality_prediction(article_title, revision_id):
    """
    This function takes an article title and its Wikipedia revision ID, sends a request to the ORES API to 
    get the article's quality prediction, and returns the predicted quality score (e.g., 'FA', 'GA', etc.).
    """
    try:
        # Construct the full URL for querying ORES API with the model and revision ID
        ores_url = f"{ORES_ENDPOINT}?models={ORES_MODEL}&revids={revision_id}"
        
        # Send a GET request to the ORES API to fetch the quality prediction
        response = requests.get(ores_url)

        # Check if the request was successful (HTTP status 200)
        if response.status_code == 200:
            # Parse the JSON response to extract the predicted quality score
            data = response.json()
            # Navigate to the specific part of the response that holds the prediction for the revision ID
            scores = data['enwiki']['scores'][str(revision_id)]['wp10']['score']['prediction']
            return scores  # Return the quality prediction (e.g., 'FA', 'GA')
        else:
            # Handle cases where the API request fails (e.g., bad response)
            print(f"Failed to get ORES score for {article_title} (Revision ID: {revision_id})")
            return None
    except Exception as e:
        # Handle any exceptions (e.g., network or parsing issues)
        print(f"Error getting ORES score for {article_title}: {e}")
        return None

# %% [markdown]
# ## Fetching Revision IDs and Article Quality Scores
#
#
# In this section, we retrieve the **revision IDs** and **quality scores** for each politician's Wikipedia article. Using the ORES API, we classify the quality of each article based on the `wp10` model predictions.
#
# ### Steps:
# 1. **Initialize Error Logging**:
#    - We create a list `error_log` to track articles that fail to retrieve revision IDs or quality scores.
#
# 2. **Add New Columns**:
#    - We add two new columns, `revision_id` and `quality_score`, to store the retrieved data for each politician's article.
#
# 3. **Loop Through Politicians**:
#    - For each row in the `politicians_df` DataFrame, we:
#      - Extract the article title from the article URL.
#      - Request the page's revision ID using the function `request_pageinfo_per_article`.
#      - If the revision ID is retrieved successfully, we fetch the article's quality score using `get_ores_quality_prediction`.
#      - If the data is fetched successfully, it is stored in the DataFrame.
#      - Articles that fail to retrieve data are logged in the `error_log`.
#
# 4. **Save the Error Log**:
#    - The `error_log` is saved as a `.txt` file for further inspection, which can be used to debug or retry the failed articles later.
#
# 5. **Save Updated Politicians Data**:
#    - The updated DataFrame, now including revision IDs and quality scores, is saved as `articles_scores.csv`.
#
# 6. **Calculate and Print Error Rate**:
#    - The script calculates the percentage of articles that failed to retrieve a quality score, providing an error rate to assess how often the ORES API request failed.

# %%
# Initialize an empty list to log article titles that could not fetch quality scores
error_log = []

# Add columns to the politicians DataFrame to store the revision ID and quality score from the Wikipedia and ORES APIs
politicians_df['revision_id'] = None
politicians_df['quality_score'] = None

# Loop through each row (each politician) to retrieve the Wikipedia revision ID and corresponding quality score
for index, row in politicians_df.iterrows():
    # Extract the article title from the URL by splitting the string and taking the last segment after '/'
    article_title = row['url'].split('/')[-1]
    
    # Request the revision ID using the Wikipedia API
    revision_id = request_pageinfo_per_article(article_title)
    
    # If the revision ID is successfully retrieved, fetch the ORES quality score
    if revision_id:
        quality_score = get_ores_quality_prediction(article_title, revision_id)
        # Store the revision ID and quality score in the DataFrame at the respective index
        politicians_df.at[index, 'revision_id'] = revision_id
        politicians_df.at[index, 'quality_score'] = quality_score
        print(f"Data Fetched for: {revision_id}")  # Output fetched data to console for monitoring
    else:
        # If no revision ID was found, log the article title in the error log
        error_log.append(article_title)

# Save the error log to a text file to track articles where no quality score was fetched
with open('../data/ores_error_log.txt', 'w') as log_file:
    log_file.write("\n".join(error_log))

# Save the updated DataFrame with revision ID and quality score to a CSV file
politicians_df.to_csv('../data/articles_scores.csv', index=False)

# Calculate and print the error rate (i.e., the proportion of articles for which no quality score was fetched)
error_rate = len(error_log) / len(politicians_df)
print(f"Error rate: {error_rate:.2%}")
# Out:
# Data Fetched for: 1233202991
# Data Fetched for: 1230459615
# Data Fetched for: 1225661708
# Data Fetched for: 1234741562
# Data Fetched for: 1195651393
# Data Fetched for: 1235521766
# Data Fetched for: 1176429234
# Data Fetched for: 1247931713
# Data Fetched for: 1225385278
# Data Fetched for: 1226326055
# Data Fetched for: 1244521219
# Data Fetched for: 1231655023
# Data Fetched for: 1237694188
# Data Fetched for: 1227635806
# Data Fetched for: 1248505877
# Data Fetched for: 1197443408
# Data Fetched for: 1134129082
# Data Fetched for: 1193992206
# Data Fetched for: 988838315
# Data Fetched for: 949986748
# Data Fetched for: 1158302291
# Data Fetched for: 1185105938
# Data Fetched for: 1212323536
# Data Fetched for: 1245967190
# Data Fetched for: 1207743719
# Data Fetched for: 1227026187
# Data Fetched for: 1158659195
# Data Fetched for: 1240993642
# Data Fetched for: 1136611354
# Data Fetched for: 1234514565
# Data Fetched for: 1234743111
# Data Fetched for: 1179137138
# Data Fetched for: 1246566795
# Data Fetched for: 1243745950
# Data Fetched for: 1246566804
# Data Fetched for: 1235165845
# Data Fetched for: 1137130537
# Data Fetched for: 1248976824
# Data Fetched for: 1136614743
# Data Fetched for: 1238402857
# Data Fetched for: 1246566971
# Data Fetched for: 1247727443
# Data Fetched for: 1195409073
# Data Fetched for: 1176481824
# Data Fetched for: 1247762293
# Data Fetched for: 1227180106
# Data Fetched for: 1234514379
# Data Fetched for: 1246567093
# Data Fetched for: 1221720658
# Data Fetched for: 1227103354
# Data Fetched for: 1145249317
# Data Fetched for: 1235405154
# Data Fetched for: 1136630194
# Data Fetched for: 1136630129
# Data Fetched for: 1239319380
# Data Fetched for: 1223903677
# Data Fetched for: 1204109653
# Data Fetched for: 1247131367
# Data Fetched for: 1136534788
# Data Fetched for: 1136614778
# Data Fetched for: 1136614682
# Data Fetched for: 1185088733
# Data Fetched for: 1178097642
# Data Fetched for: 1129192917
# Data Fetched for: 1176507815
# Data Fetched for: 1123824802
# Data Fetched for: 1225457074
# Data Fetched for: 1225425205
# Data Fetched for: 1227951669
# Data Fetched for: 1172646418
# Data Fetched for: 1198363158
# Data Fetched for: 1242412237
# Data Fetched for: 1250972393
# Data Fetched for: 1136614726
# Data Fetched for: 1233490009
# Data Fetched for: 1227179979
# Data Fetched for: 1232389768
# Data Fetched for: 1171042170
# Data Fetched for: 1136614561
# Data Fetched for: 1243758857
# Data Fetched for: 1126667481
# Data Fetched for: 1229734414
# Data Fetched for: 1150044800
# Data Fetched for: 1245217124
# Data Fetched for: 1136614520
# Data Fetched for: 1244421894
# Data Fetched for: 1221605713
# Data Fetched for: 1192928746
# Data Fetched for: 1217284690
# Data Fetched for: 1244463139
# Data Fetched for: 1250227174
# Data Fetched for: 1250227994
# Data Fetched for: 1224650124
# Data Fetched for: 1189442848
# Data Fetched for: 1196422551
# Data Fetched for: 1222381064
# Data Fetched for: 1184807608
# Data Fetched for: 1198914812
# Data Fetched for: 1248264998
# Data Fetched for: 1209346411
# Data Fetched for: 1244008227
# Data Fetched for: 1222151681
# Data Fetched for: 1209165678
# Data Fetched for: 1180949327
# Data Fetched for: 1236738861
# Data Fetched for: 1236738502
# Data Fetched for: 1243882903
# Data Fetched for: 1240801210
# Data Fetched for: 1198224146
# Data Fetched for: 1241037317
# Data Fetched for: 1230739582
# Data Fetched for: 1226635783
# Data Fetched for: 1229938943
# Data Fetched for: 1245450388
# Data Fetched for: 1244486529
# Data Fetched for: 1145510350
# Data Fetched for: 1098236555
# Data Fetched for: 1235824719
# Data Fetched for: 1227369252
# Data Fetched for: 1237006808
# Data Fetched for: 1237950375
# Data Fetched for: 1174010569
# Data Fetched for: 1209148780
# Data Fetched for: 1236739222
# Data Fetched for: 1112281132
# Data Fetched for: 1180950536
# Data Fetched for: 1180950488
# Data Fetched for: 1227760361
# Data Fetched for: 1234673487
# Data Fetched for: 1218412314
# Data Fetched for: 1235824584
# Data Fetched for: 1198219291
# Data Fetched for: 1180949734
# Data Fetched for: 1196135017
# Data Fetched for: 1240539074
# Data Fetched for: 1180949774
# Data Fetched for: 1220757655
# Data Fetched for: 1198167947
# Data Fetched for: 1215667416
# Data Fetched for: 1229276965
# Data Fetched for: 1141930406
# Data Fetched for: 1244486537
# Data Fetched for: 1173107489
# Data Fetched for: 1250811470
# Data Fetched for: 1220369492
# Data Fetched for: 1217259369
# Data Fetched for: 1239924043
# Data Fetched for: 1228151428
# Data Fetched for: 1241836925
# Data Fetched for: 1186986269
# Data Fetched for: 1135323365
# Data Fetched for: 1248230838
# Data Fetched for: 1220281072
# Data Fetched for: 1143896123
# Data Fetched for: 1235824554
# Data Fetched for: 1250270534
# Data Fetched for: 1234096174
# Data Fetched for: 1214835889
# Data Fetched for: 1192088820
# Data Fetched for: 1226280389
# Data Fetched for: 1099284595
# Data Fetched for: 1111537825
# Data Fetched for: 1219685755
# Data Fetched for: 1218173615
# Data Fetched for: 1241671793
# Data Fetched for: 1214832676
# Data Fetched for: 1176411375
# Data Fetched for: 1239235131
# Data Fetched for: 1226553342
# Data Fetched for: 1169278443
# Data Fetched for: 1237478919
# Data Fetched for: 1134649751
# Data Fetched for: 1245801726
# Data Fetched for: 1235672021
# Data Fetched for: 1217131488
# Data Fetched for: 1212186965
# Data Fetched for: 1249963763
# Data Fetched for: 1186319378
# Data Fetched for: 1240883461
# Data Fetched for: 1232492563
# Data Fetched for: 1203569345
# Data Fetched for: 1230623499
# Data Fetched for: 1186319308
# Data Fetched for: 1224118485
# Data Fetched for: 1242037866
# Data Fetched for: 1248318178
# Data Fetched for: 1242619010
# Data Fetched for: 1220757834
# Data Fetched for: 1230435685
# Data Fetched for: 1053460621
# Data Fetched for: 1214834266
# Data Fetched for: 1244337610
# Data Fetched for: 1213344636
# Data Fetched for: 1213342432
# Data Fetched for: 1227200392
# Data Fetched for: 1226437538
# Data Fetched for: 1218302579
# Data Fetched for: 1226452639
# Data Fetched for: 1226271746
# Data Fetched for: 1172500304
# Data Fetched for: 1213795388
# Data Fetched for: 1181986973
# Data Fetched for: 1053469610
# Data Fetched for: 1235394946
# Data Fetched for: 1214841607
# Data Fetched for: 1244511083
# Data Fetched for: 1186318318
# Data Fetched for: 1233387309
# Data Fetched for: 1213870570
# Data Fetched for: 1226279231
# Data Fetched for: 1212181372
# Data Fetched for: 1226335614
# Data Fetched for: 1214837789
# Data Fetched for: 1053461144
# Data Fetched for: 1186317568
# Data Fetched for: 1248662394
# Data Fetched for: 1215901775
# Data Fetched for: 1229426851
# Data Fetched for: 1218004839
# Data Fetched for: 1212186286
# Data Fetched for: 1213404244
# Data Fetched for: 1212579707
# Data Fetched for: 1218530483
# Data Fetched for: 1213794210
# Data Fetched for: 1226060720
# Data Fetched for: 1213778323
# Data Fetched for: 1209524394
# Data Fetched for: 1209514022
# Data Fetched for: 1172178750
# Data Fetched for: 1242307496
# Data Fetched for: 1210193481
# Data Fetched for: 1227794006
# Data Fetched for: 1241977204
# Data Fetched for: 1177486404
# Data Fetched for: 1191431794
# Data Fetched for: 1220287872
# Data Fetched for: 1165626565
# Data Fetched for: 1217387083
# Data Fetched for: 1244123151
# Data Fetched for: 1242000475
# Data Fetched for: 1194150567
# Data Fetched for: 1158035855
# Data Fetched for: 1209522689
# Data Fetched for: 1251032908
# Data Fetched for: 1124441544
# Data Fetched for: 1242307432
# Data Fetched for: 1242307441
# Data Fetched for: 1242307337
# Data Fetched for: 1093124425
# Data Fetched for: 1209631313
# Data Fetched for: 1209411144
# Data Fetched for: 1209411217
# Data Fetched for: 1209413818
# Data Fetched for: 1218506469
# Data Fetched for: 1209513699
# Data Fetched for: 1024544204
# Data Fetched for: 1251004422
# Data Fetched for: 1241977176
# Data Fetched for: 1209539718
# Data Fetched for: 1154991360
# Data Fetched for: 1227909121
# Data Fetched for: 1187961349
# Data Fetched for: 1209410923
# Data Fetched for: 1115715527
# Data Fetched for: 1220287990
# Data Fetched for: 1242307359
# Data Fetched for: 1165626399
# Data Fetched for: 1250824530
# Data Fetched for: 1242307479
# Data Fetched for: 1153488959
# Data Fetched for: 1246271741
# Data Fetched for: 1242306989
# Data Fetched for: 1142474441
# Data Fetched for: 1226309621
# Data Fetched for: 1228399791
# Data Fetched for: 1246026420
# Data Fetched for: 1118804168
# Data Fetched for: 1233607984
# Data Fetched for: 1219179734
# Data Fetched for: 1242841039
# Data Fetched for: 1227004140
# Data Fetched for: 1240720719
# Data Fetched for: 1250493481
# Data Fetched for: 1243272129
# Data Fetched for: 1241563106
# Data Fetched for: 1247631912
# Data Fetched for: 825090349
# Data Fetched for: 1247631794
# Data Fetched for: 1241563118
# Data Fetched for: 1242152285
# Data Fetched for: 1241563122
# Data Fetched for: 1247632329
# Data Fetched for: 1241563130
# Data Fetched for: 1241563135
# Data Fetched for: 1241563138
# Data Fetched for: 1250666577
# Data Fetched for: 1227026341
# Data Fetched for: 1242813942
# Data Fetched for: 1246340247
# Data Fetched for: 1213836084
# Data Fetched for: 1247632301
# Data Fetched for: 1247632282
# Data Fetched for: 1241563151
# Data Fetched for: 1241592202
# Data Fetched for: 1241564680
# Data Fetched for: 1248648606
# Data Fetched for: 1247632248
# Data Fetched for: 1241592526
# Data Fetched for: 1247631631
# Data Fetched for: 1247514093
# Data Fetched for: 1241592535
# Data Fetched for: 1247632364
# Data Fetched for: 1241564686
# Data Fetched for: 1241592215
# Data Fetched for: 1247632342
# Data Fetched for: 1247632346
# Data Fetched for: 1241592542
# Data Fetched for: 1227499891
# Data Fetched for: 1223272051
# Data Fetched for: 1227458965
# Data Fetched for: 1217815148
# Data Fetched for: 1217815124
# Data Fetched for: 1233010330
# Data Fetched for: 1229623675
# Data Fetched for: 1225811362
# Data Fetched for: 1243926512
# Data Fetched for: 1250713562
# Data Fetched for: 1225775647
# Data Fetched for: 1188044851
# Data Fetched for: 1135193654
# Data Fetched for: 1166331326
# Data Fetched for: 1231276700
# Data Fetched for: 1245130520
# Data Fetched for: 1227517224
# Data Fetched for: 1232135530
# Data Fetched for: 1227620960
# Data Fetched for: 1227459720
# Data Fetched for: 1209668330
# Data Fetched for: 1225784914
# Data Fetched for: 1234469779
# Data Fetched for: 1243279888
# Data Fetched for: 1067754685
# Data Fetched for: 1245178482
# Data Fetched for: 1148828249
# Data Fetched for: 1039135531
# Data Fetched for: 1227616001
# Data Fetched for: 1225793565
# Data Fetched for: 1225793589
# Data Fetched for: 1227515965
# Data Fetched for: 1162056054
# Data Fetched for: 1217866134
# Data Fetched for: 1240898573
# Data Fetched for: 1225799546
# Data Fetched for: 1225799869
# Data Fetched for: 1248572448
# Data Fetched for: 1234698824
# Data Fetched for: 797826672
# Data Fetched for: 1210433646
# Data Fetched for: 1222899462
# Data Fetched for: 1247590161
# Data Fetched for: 1166892817
# Data Fetched for: 1096175549
# Data Fetched for: 1248788227
# Data Fetched for: 1242262794
# Data Fetched for: 1238199017
# Data Fetched for: 1193099129
# Data Fetched for: 1228141029
# Data Fetched for: 1226445117
# Data Fetched for: 1211044406
# Data Fetched for: 1199679676
# Data Fetched for: 1138003698
# Data Fetched for: 1106856167
# Data Fetched for: 1245068036
# Data Fetched for: 1016343362
# Data Fetched for: 1226040049
# Data Fetched for: 1166890663
# Data Fetched for: 1195011460
# Data Fetched for: 1222501416
# Data Fetched for: 1245464700
# Data Fetched for: 1227361697
# Data Fetched for: 1191859791
# Data Fetched for: 1218601969
# Data Fetched for: 1124301399
# Data Fetched for: 1231768992
# Data Fetched for: 1103745376
# Data Fetched for: 1214660598
# Data Fetched for: 1180063729
# Data Fetched for: 1214660728
# Data Fetched for: 1214660921
# Data Fetched for: 1224369324
# Data Fetched for: 1231946069
# Data Fetched for: 1237979345
# Data Fetched for: 1226313476
# Data Fetched for: 1250311867
# Data Fetched for: 1210493386
# Data Fetched for: 1214661551
# Data Fetched for: 1180063778
# Data Fetched for: 1214661649
# Data Fetched for: 1228290809
# Data Fetched for: 1214661775
# Data Fetched for: 1214662146
# Data Fetched for: 1233470777
# Data Fetched for: 1240224564
# Data Fetched for: 1214986895
# Data Fetched for: 1215924661
# Data Fetched for: 1249622641
# Data Fetched for: 1214662694
# Data Fetched for: 1243510830
# Data Fetched for: 1217803359
# Data Fetched for: 1214669503
# Data Fetched for: 1214669611
# Data Fetched for: 1242146414
# Data Fetched for: 1215201883
# Data Fetched for: 1243511026
# Data Fetched for: 1243494457
# Data Fetched for: 1214670011
# Data Fetched for: 1222543352
# Data Fetched for: 1244617588
# Data Fetched for: 1244447844
# Data Fetched for: 1226152632
# Data Fetched for: 1214670404
# Data Fetched for: 1228353209
# Data Fetched for: 1214670744
# Data Fetched for: 1237091760
# Data Fetched for: 1214682376
# Data Fetched for: 1200893975
# Data Fetched for: 1243336388
# Data Fetched for: 1251039794
# Data Fetched for: 1231555745
# Data Fetched for: 1216075327
# Data Fetched for: 1240489075
# Data Fetched for: 1223497595
# Data Fetched for: 1154443829
# Data Fetched for: 1216088776
# Data Fetched for: 1232067132
# Data Fetched for: 1226351964
# Data Fetched for: 1215043658
# Data Fetched for: 1215043825
# Data Fetched for: 1215044008
# Data Fetched for: 1215045853
# Data Fetched for: 1215044432
# Data Fetched for: 1215046038
# Data Fetched for: 1214236945
# Data Fetched for: 1242771327
# Data Fetched for: 1225140706
# Data Fetched for: 1169137921
# Data Fetched for: 1215046740
# Data Fetched for: 1106829544
# Data Fetched for: 1242552103
# Data Fetched for: 1242810704
# Data Fetched for: 1241392879
# Data Fetched for: 1215053905
# Data Fetched for: 1235730032
# Data Fetched for: 1215054152
# Data Fetched for: 1215483185
# Data Fetched for: 1248432097
# Data Fetched for: 1250933660
# Data Fetched for: 1231556108
# Data Fetched for: 1215054486
# Data Fetched for: 1099978355
# Data Fetched for: 1250188481
# Data Fetched for: 1250934182
# Data Fetched for: 1226209962
# Data Fetched for: 1228417930
# Data Fetched for: 1226214871
# Data Fetched for: 1246630894
# Data Fetched for: 1215184008
# Data Fetched for: 1242446030
# Data Fetched for: 1248404055
# Data Fetched for: 1238011369
# Data Fetched for: 1249288737
# Data Fetched for: 1251056800
# Data Fetched for: 1215185462
# Data Fetched for: 1236098636
# Data Fetched for: 1215185628
# Data Fetched for: 1215185845
# Data Fetched for: 1239601735
# Data Fetched for: 1215186109
# Data Fetched for: 1235856770
# Data Fetched for: 1215186237
# Data Fetched for: 1246777408
# Data Fetched for: 1215186443
# Data Fetched for: 1240951343
# Data Fetched for: 1153989705
# Data Fetched for: 1215186791
# Data Fetched for: 1231556362
# Data Fetched for: 1231556425
# Data Fetched for: 1215187415
# Data Fetched for: 1215187552
# Data Fetched for: 1243965585
# Data Fetched for: 1240906258
# Data Fetched for: 1223484511
# Data Fetched for: 1230366514
# Data Fetched for: 1243626881
# Data Fetched for: 1250642641
# Data Fetched for: 1211047878
# Data Fetched for: 1161577254
# Data Fetched for: 1240965677
# Data Fetched for: 1236388140
# Data Fetched for: 1246060446
# Data Fetched for: 1237483914
# Data Fetched for: 1213943020
# Data Fetched for: 1245503366
# Data Fetched for: 1247420701
# Data Fetched for: 1207600921
# Data Fetched for: 1199215674
# Data Fetched for: 1246060690
# Data Fetched for: 1207738330
# Data Fetched for: 1226415908
# Data Fetched for: 1208072134
# Data Fetched for: 1241052691
# Data Fetched for: 1243509483
# Data Fetched for: 1243747432
# Data Fetched for: 1246060699
# Data Fetched for: 1234004989
# Data Fetched for: 1067081975
# Data Fetched for: 1232296078
# Data Fetched for: 1237445893
# Data Fetched for: 1236490449
# Data Fetched for: 1235219197
# Data Fetched for: 1239189558
# Data Fetched for: 1246286594
# Data Fetched for: 1236490430
# Data Fetched for: 1244589428
# Data Fetched for: 1248447237
# Data Fetched for: 1245282668
# Data Fetched for: 1224596001
# Data Fetched for: 1245270394
# Data Fetched for: 1246588423
# Data Fetched for: 1244157806
# Data Fetched for: 1225308278
# Data Fetched for: 1244201378
# Data Fetched for: 1249203876
# Data Fetched for: 1157124148
# Data Fetched for: 1222623261
# Data Fetched for: 1228687346
# Data Fetched for: 1147579900
# Data Fetched for: 1250266366
# Data Fetched for: 1245270299
# Data Fetched for: 1217681945
# Data Fetched for: 1243520102
# Data Fetched for: 1187254621
# Data Fetched for: 1226230854
# Data Fetched for: 1011331249
# Data Fetched for: 1243510539
# Data Fetched for: 1248225337
# Data Fetched for: 1243510550
# Data Fetched for: 1248662299
# Data Fetched for: 1194162044
# Data Fetched for: 1210593900
# Data Fetched for: 1241255046
# Data Fetched for: 1248662296
# Data Fetched for: 1206211739
# Data Fetched for: 1158375491
# Data Fetched for: 1243520070
# Data Fetched for: 1213965350
# Data Fetched for: 1245157534
# Data Fetched for: 1193027962
# Data Fetched for: 1106104383
# Data Fetched for: 1208078338
# Data Fetched for: 1148385245
# Data Fetched for: 1198202282
# Data Fetched for: 1213858589
# Data Fetched for: 1185599926
# Data Fetched for: 1243510547
# Data Fetched for: 1213002608
# Data Fetched for: 1243510572
# Data Fetched for: 1249675761
# Data Fetched for: 1208077047
# Data Fetched for: 1243510546
# Data Fetched for: 1243510541
# Data Fetched for: 1243023554
# Data Fetched for: 1162793449
# Data Fetched for: 1142294843
# Data Fetched for: 1245586658
# Data Fetched for: 1181612386
# Data Fetched for: 1177467150
# Data Fetched for: 1238577650
# Data Fetched for: 1226025677
# Data Fetched for: 1248344476
# Data Fetched for: 1171757402
# Data Fetched for: 1223700072
# Data Fetched for: 1182830303
# Data Fetched for: 1063482737
# Data Fetched for: 1215486840
# Data Fetched for: 1006173162
# Data Fetched for: 1215466172
# Data Fetched for: 1227286508
# Data Fetched for: 1241906132
# Data Fetched for: 1161492589
# Data Fetched for: 1231654401
# Data Fetched for: 1177286981
# Data Fetched for: 1099067663
# Data Fetched for: 1218302538
# Data Fetched for: 1159628135
# Data Fetched for: 1098344827
# Data Fetched for: 1148959062
# Data Fetched for: 1146485875
# Data Fetched for: 1172576081
# Data Fetched for: 1098699647
# Data Fetched for: 1006167519
# Data Fetched for: 1241499929
# Data Fetched for: 1221144846
# Data Fetched for: 1251095347
# Data Fetched for: 1232948277
# Data Fetched for: 1156409493
# Data Fetched for: 1217876419
# Data Fetched for: 1247375519
# Data Fetched for: 1233118749
# Data Fetched for: 1227285970
# Data Fetched for: 1247375502
# Data Fetched for: 1209519423
# Data Fetched for: 1195787872
# Data Fetched for: 1063213013
# Data Fetched for: 1244455253
# Data Fetched for: 1202322111
# Data Fetched for: 1235804624
# Data Fetched for: 1140605737
# Data Fetched for: 1249444464
# Data Fetched for: 1219928150
# Data Fetched for: 1239617504
# Data Fetched for: 1244755894
# Data Fetched for: 1250494329
# Data Fetched for: 1245374567
# Data Fetched for: 1245374007
# Data Fetched for: 1232200030
# Data Fetched for: 1247061966
# Data Fetched for: 1237261756
# Data Fetched for: 1245375794
# Data Fetched for: 1245380189
# Data Fetched for: 1246694478
# Data Fetched for: 1245377984
# Data Fetched for: 1242815841
# Data Fetched for: 1245379837
# Data Fetched for: 1250896485
# Data Fetched for: 1245380479
# Data Fetched for: 1245374148
# Data Fetched for: 1183475136
# Data Fetched for: 1236303322
# Data Fetched for: 1246126702
# Data Fetched for: 1242147738
# Data Fetched for: 1245380545
# Data Fetched for: 1175807916
# Data Fetched for: 1245395466
# Data Fetched for: 1166369458
# Data Fetched for: 1245377291
# Data Fetched for: 1245379554
# Data Fetched for: 1228415190
# Data Fetched for: 1230176939
# Data Fetched for: 1242126632
# Data Fetched for: 1212687396
# Data Fetched for: 1237265302
# Data Fetched for: 1240939624
# Data Fetched for: 1242257552
# Data Fetched for: 1245402550
# Data Fetched for: 1245394398
# Data Fetched for: 1226325755
# Data Fetched for: 1245378724
# Data Fetched for: 1247693188
# Data Fetched for: 1247089625
# Data Fetched for: 1232782976
# Data Fetched for: 1245380771
# Data Fetched for: 1237261567
# Data Fetched for: 1249497016
# Data Fetched for: 1244156514
# Data Fetched for: 1237261507
# Data Fetched for: 1247242676
# Data Fetched for: 1245374454
# Data Fetched for: 1117752666
# Data Fetched for: 1245961260
# Data Fetched for: 1066093324
# Data Fetched for: 1245374542
# Data Fetched for: 1243563371
# Data Fetched for: 1241208220
# Data Fetched for: 1245374586
# Data Fetched for: 1245978368
# Data Fetched for: 1246459927
# Data Fetched for: 1232199873
# Data Fetched for: 1225060231
# Data Fetched for: 1250961688
# Data Fetched for: 1245374666
# Data Fetched for: 1250599443
# Data Fetched for: 1245395381
# Data Fetched for: 1242580877
# Data Fetched for: 1250725167
# Data Fetched for: 1247376048
# Data Fetched for: 1250491967
# Data Fetched for: 1067136662
# Data Fetched for: 1246347372
# Data Fetched for: 1245376617
# Data Fetched for: 1245374793
# Data Fetched for: 1237264157
# Data Fetched for: 1247669907
# Data Fetched for: 1046006361
# Data Fetched for: 1220769997
# Data Fetched for: 1237263822
# Data Fetched for: 1245374883
# Data Fetched for: 1242611945
# Data Fetched for: 1239861059
# Data Fetched for: 1225635388
# Data Fetched for: 1080633319
# Data Fetched for: 1090468579
# Data Fetched for: 1149070233
# Data Fetched for: 1223215475
# Data Fetched for: 1079840895
# Data Fetched for: 1200176178
# Data Fetched for: 1245455194
# Data Fetched for: 1123730836
# Data Fetched for: 1219669780
# Data Fetched for: 1132713774
# Data Fetched for: 1079886049
# Data Fetched for: 1123554066
# Data Fetched for: 1090593974
# Data Fetched for: 1191591712
# Data Fetched for: 1248634872
# Data Fetched for: 1218309623
# Data Fetched for: 1236388821
# Data Fetched for: 1227284229
# Data Fetched for: 1126117422
# Data Fetched for: 1232133512
# Data Fetched for: 1226875792
# Data Fetched for: 1226922424
# Data Fetched for: 1172992483
# Data Fetched for: 1249779544
# Data Fetched for: 1237691839
# Data Fetched for: 1177364352
# Data Fetched for: 1244903816
# Data Fetched for: 1245495829
# Data Fetched for: 1115164729
# Data Fetched for: 1173907794
# Data Fetched for: 1225610619
# Data Fetched for: 1226775102
# Data Fetched for: 1105545058
# Data Fetched for: 1217471500
# Data Fetched for: 1224032323
# Data Fetched for: 1234751055
# Data Fetched for: 1205140753
# Data Fetched for: 1250542933
# Data Fetched for: 1243510259
# Data Fetched for: 1147914902
# Data Fetched for: 1248009248
# Data Fetched for: 1249602665
# Data Fetched for: 1144551736
# Data Fetched for: 1246821242
# Data Fetched for: 1235204307
# Data Fetched for: 1228551886
# Data Fetched for: 1216932338
# Data Fetched for: 1216629323
# Data Fetched for: 1236837678
# Data Fetched for: 1064451133
# Data Fetched for: 1250695986
# Data Fetched for: 1214790691
# Data Fetched for: 1246263655
# Data Fetched for: 1206663730
# Data Fetched for: 1245626600
# Data Fetched for: 1243221482
# Data Fetched for: 1247883595
# Data Fetched for: 1245495069
# Data Fetched for: 1173778739
# Data Fetched for: 1244677659
# Data Fetched for: 1243935880
# Data Fetched for: 1243531072
# Data Fetched for: 1241935456
# Data Fetched for: 1231554975
# Data Fetched for: 1243748019
# Data Fetched for: 1161024456
# Data Fetched for: 1233502726
# Data Fetched for: 1250972147
# Data Fetched for: 1179322005
# Data Fetched for: 1243330963
# Data Fetched for: 1222825457
# Data Fetched for: 1058540061
# Data Fetched for: 1226437075
# Data Fetched for: 1244830798
# Data Fetched for: 1221734112
# Data Fetched for: 1140361651
# Data Fetched for: 1165947877
# Data Fetched for: 1248580125
# Data Fetched for: 1165734903
# Data Fetched for: 1233546471
# Data Fetched for: 1173454330
# Data Fetched for: 1231555121
# Data Fetched for: 1225811527
# Data Fetched for: 1202217968
# Data Fetched for: 1250856746
# Data Fetched for: 1249790591
# Data Fetched for: 1224617580
# Data Fetched for: 1246136139
# Data Fetched for: 1182389599
# Data Fetched for: 1149315537
# Data Fetched for: 1112290249
# Data Fetched for: 1226329636
# Data Fetched for: 1217126753
# Data Fetched for: 1051591828
# Data Fetched for: 1235711895
# Data Fetched for: 1194388133
# Data Fetched for: 1215066294
# Data Fetched for: 1139979372
# Data Fetched for: 1109576011
# Data Fetched for: 1145182533
# Data Fetched for: 1136575793
# Data Fetched for: 1183327367
# Data Fetched for: 1189630357
# Data Fetched for: 1226460856
# Data Fetched for: 1136573750
# Data Fetched for: 1212308026
# Data Fetched for: 1198582609
# Data Fetched for: 1243748075
# Data Fetched for: 1105018002
# Data Fetched for: 1188233504
# Data Fetched for: 1178923770
# Data Fetched for: 1251093424
# Data Fetched for: 1190357309
# Data Fetched for: 1179788619
# Data Fetched for: 1237243541
# Data Fetched for: 1140972331
# Data Fetched for: 1233498632
# Data Fetched for: 1233204055
# Data Fetched for: 1143555621
# Data Fetched for: 1236873042
# Data Fetched for: 1029822060
# Data Fetched for: 1249920109
# Data Fetched for: 1233472654
# Data Fetched for: 1044386557
# Data Fetched for: 1244463135
# Data Fetched for: 1243748132
# Data Fetched for: 1073906467
# Data Fetched for: 1224501115
# Data Fetched for: 1227001179
# Data Fetched for: 1136564688
# Data Fetched for: 1136613172
# Data Fetched for: 1247551813
# Data Fetched for: 1250929396
# Data Fetched for: 1235733819
# Data Fetched for: 1058900581
# Data Fetched for: 1175107156
# Data Fetched for: 1185742670
# Data Fetched for: 1162861355
# Data Fetched for: 1216990637
# Data Fetched for: 1242446129
# Data Fetched for: 1171859695
# Data Fetched for: 1247370983
# Data Fetched for: 1239031792
# Data Fetched for: 1247370963
# Data Fetched for: 1225001639
# Data Fetched for: 1215561378
# Data Fetched for: 1237091310
# Data Fetched for: 1170437413
# Data Fetched for: 1248386169
# Data Fetched for: 1197447438
# Data Fetched for: 1244960174
# Data Fetched for: 1212917164
# Data Fetched for: 1192236303
# Data Fetched for: 1162194883
# Data Fetched for: 1226923015
# Data Fetched for: 1060085965
# Data Fetched for: 1243793309
# Data Fetched for: 1068932528
# Data Fetched for: 986218104
# Data Fetched for: 967051066
# Data Fetched for: 1151261156
# Data Fetched for: 1154610749
# Data Fetched for: 986219619
# Data Fetched for: 1205968589
# Data Fetched for: 1134603390
# Data Fetched for: 1135378735
# Data Fetched for: 1157335890
# Data Fetched for: 1250417464
# Data Fetched for: 1157055139
# Data Fetched for: 1226646329
# Data Fetched for: 1241911285
# Data Fetched for: 1250135261
# Data Fetched for: 1029727171
# Data Fetched for: 1154435788
# Data Fetched for: 1184305239
# Data Fetched for: 1247671463
# Data Fetched for: 1140545677
# Data Fetched for: 1240180535
# Data Fetched for: 1151281659
# Data Fetched for: 1244166908
# Data Fetched for: 1211978424
# Data Fetched for: 1205736909
# Data Fetched for: 1220863731
# Data Fetched for: 1226645464
# Data Fetched for: 1216960207
# Data Fetched for: 1076705305
# Data Fetched for: 1242666773
# Data Fetched for: 1225408958
# Data Fetched for: 1105642733
# Data Fetched for: 1227847643
# Data Fetched for: 1150559998
# Data Fetched for: 935053725
# Data Fetched for: 1010522641
# Data Fetched for: 1198222416
# Data Fetched for: 1212616003
# Data Fetched for: 1244820972
# Data Fetched for: 1179648130
# Data Fetched for: 1245331050
# Data Fetched for: 992221311
# Data Fetched for: 1015285975
# Data Fetched for: 1060153270
# Data Fetched for: 1200012565
# Data Fetched for: 1142925183
# Data Fetched for: 1177678990
# Data Fetched for: 1185452679
# Data Fetched for: 1189186057
# Data Fetched for: 1226514494
# Data Fetched for: 1227518824
# Data Fetched for: 1227518654
# Data Fetched for: 1226316088
# Data Fetched for: 1231708987
# Data Fetched for: 1248979046
# Data Fetched for: 1241844844
# Data Fetched for: 1227643398
# Data Fetched for: 1228024668
# Data Fetched for: 1219316021
# Data Fetched for: 1064844718
# Data Fetched for: 1239045289
# Data Fetched for: 1242300969
# Data Fetched for: 1219966135
# Data Fetched for: 1214469646
# Data Fetched for: 1234177241
# Data Fetched for: 1234930001
# Data Fetched for: 1226589407
# Data Fetched for: 1227718125
# Data Fetched for: 1237235215
# Data Fetched for: 1249373475
# Data Fetched for: 1250888240
# Data Fetched for: 1195939890
# Data Fetched for: 1102912474
# Data Fetched for: 1227642782
# Data Fetched for: 1218741477
# Data Fetched for: 1229058411
# Data Fetched for: 1242412154
# Data Fetched for: 1250318982
# Data Fetched for: 1153745598
# Data Fetched for: 1152217397
# Data Fetched for: 1248877827
# Data Fetched for: 1177822723
# Data Fetched for: 1220369102
# Data Fetched for: 1239849237
# Data Fetched for: 1208916358
# Data Fetched for: 1208918047
# Data Fetched for: 1230312593
# Data Fetched for: 1240877452
# Data Fetched for: 1241231943
# Data Fetched for: 1232585595
# Data Fetched for: 1242157045
# Data Fetched for: 1234052579
# Data Fetched for: 1247049881
# Data Fetched for: 1244486253
# Data Fetched for: 1245241762
# Data Fetched for: 1243518890
# Data Fetched for: 1227279651
# Data Fetched for: 1191081387
# Data Fetched for: 1248791274
# Data Fetched for: 1224295220
# Data Fetched for: 1227059736
# Data Fetched for: 1208917045
# Data Fetched for: 1229796197
# Data Fetched for: 1175001666
# Data Fetched for: 1245042669
# Data Fetched for: 1231812222
# Data Fetched for: 1184510646
# Data Fetched for: 1195934285
# Data Fetched for: 1197296458
# Data Fetched for: 1244979237
# Data Fetched for: 1156216427
# Data Fetched for: 1202430663
# Data Fetched for: 1231181406
# Data Fetched for: 1198617659
# Data Fetched for: 1246499104
# Data Fetched for: 1214253428
# Data Fetched for: 1243511577
# Data Fetched for: 1242397174
# Data Fetched for: 1221047215
# Data Fetched for: 1246418220
# Data Fetched for: 1178476996
# Data Fetched for: 1247394394
# Data Fetched for: 1226478932
# Data Fetched for: 1176588076
# Data Fetched for: 1182796131
# Data Fetched for: 1224035109
# Data Fetched for: 1248173582
# Data Fetched for: 1153333232
# Data Fetched for: 1199631944
# Data Fetched for: 1180933919
# Data Fetched for: 1117645422
# Data Fetched for: 1246064882
# Data Fetched for: 1194912644
# Data Fetched for: 1218000288
# Data Fetched for: 1250050202
# Data Fetched for: 1226004242
# Data Fetched for: 1246064910
# Data Fetched for: 1234976623
# Data Fetched for: 1232482469
# Data Fetched for: 1237350838
# Data Fetched for: 1100962574
# Data Fetched for: 1241496689
# Data Fetched for: 1232075289
# Data Fetched for: 1247550991
# Data Fetched for: 1101206546
# Data Fetched for: 1159365191
# Data Fetched for: 1232135695
# Data Fetched for: 1234365972
# Data Fetched for: 1232431995
# Data Fetched for: 1194157482
# Data Fetched for: 1187809146
# Data Fetched for: 1217010787
# Data Fetched for: 1228999761
# Data Fetched for: 1159362123
# Data Fetched for: 1191964237
# Data Fetched for: 1176844004
# Data Fetched for: 1250026721
# Data Fetched for: 1246786160
# Data Fetched for: 1222167969
# Data Fetched for: 1240746354
# Data Fetched for: 1226520601
# Data Fetched for: 1223962625
# Data Fetched for: 1101206516
# Data Fetched for: 1225265033
# Data Fetched for: 1240160240
# Data Fetched for: 1242607162
# Data Fetched for: 1247551254
# Data Fetched for: 1221098764
# Data Fetched for: 1251007551
# Data Fetched for: 1226009834
# Data Fetched for: 1248440839
# Data Fetched for: 1245729965
# Data Fetched for: 1233198027
# Data Fetched for: 1238920549
# Data Fetched for: 1242250612
# Data Fetched for: 1246064580
# Data Fetched for: 1087824575
# Data Fetched for: 1218280310
# Data Fetched for: 1235664468
# Data Fetched for: 1242343796
# Data Fetched for: 1208121039
# Data Fetched for: 1246065514
# Data Fetched for: 1178155220
# Data Fetched for: 1249279029
# Data Fetched for: 1088472912
# Data Fetched for: 1225818171
# Data Fetched for: 1240167587
# Data Fetched for: 1221332843
# Data Fetched for: 1249739851
# Data Fetched for: 1146046975
# Data Fetched for: 1246065571
# Data Fetched for: 1227539038
# Data Fetched for: 1247853934
# Data Fetched for: 1240095314
# Data Fetched for: 1247854957
# Data Fetched for: 1247855190
# Data Fetched for: 1247853887
# Data Fetched for: 1226012000
# Data Fetched for: 1251079168
# Data Fetched for: 1240228814
# Data Fetched for: 1245624959
# Data Fetched for: 1249338218
# Data Fetched for: 1248725167
# Data Fetched for: 1232333312
# Data Fetched for: 1193380607
# Data Fetched for: 1246064759
# Data Fetched for: 1230117539
# Data Fetched for: 1184506048
# Data Fetched for: 1168433608
# Data Fetched for: 1239452174
# Data Fetched for: 1232432585
# Data Fetched for: 1246065682
# Data Fetched for: 1015210781
# Data Fetched for: 1249997750
# Data Fetched for: 1163771893
# Data Fetched for: 1246603749
# Data Fetched for: 1243281944
# Data Fetched for: 1014343460
# Data Fetched for: 1201215647
# Data Fetched for: 1149938942
# Data Fetched for: 1246449214
# Data Fetched for: 1216910276
# Data Fetched for: 1188242249
# Data Fetched for: 1191804969
# Data Fetched for: 1232505950
# Data Fetched for: 1215311752
# Data Fetched for: 1215311929
# Data Fetched for: 1241175591
# Data Fetched for: 1236766093
# Data Fetched for: 1239086809
# Data Fetched for: 1215320743
# Data Fetched for: 1238466176
# Data Fetched for: 1222513400
# Data Fetched for: 1242153001
# Data Fetched for: 1227609197
# Data Fetched for: 1245989144
# Data Fetched for: 1215313341
# Data Fetched for: 1215313537
# Data Fetched for: 1215314052
# Data Fetched for: 1236020876
# Data Fetched for: 1249080975
# Data Fetched for: 1215314240
# Data Fetched for: 1215314438
# Data Fetched for: 1240457984
# Data Fetched for: 1243679989
# Data Fetched for: 1244496816
# Data Fetched for: 1215314724
# Data Fetched for: 1246703703
# Data Fetched for: 1215314827
# Data Fetched for: 1250148087
# Data Fetched for: 1183947838
# Data Fetched for: 1215315466
# Data Fetched for: 1244548670
# Data Fetched for: 1244791314
# Data Fetched for: 1215315664
# Data Fetched for: 1242153020
# Data Fetched for: 1236793256
# Data Fetched for: 1215860047
# Data Fetched for: 1246693713
# Data Fetched for: 1215315878
# Data Fetched for: 1235730767
# Data Fetched for: 1180593616
# Data Fetched for: 1243605333
# Data Fetched for: 1241562603
# Data Fetched for: 1159601677
# Data Fetched for: 1133046866
# Data Fetched for: 1236796256
# Data Fetched for: 1022365931
# Data Fetched for: 1211256598
# Data Fetched for: 1208372103
# Data Fetched for: 1240500207
# Data Fetched for: 1242211308
# Data Fetched for: 1243979008
# Data Fetched for: 1192998630
# Data Fetched for: 1236772129
# Data Fetched for: 1189228353
# Data Fetched for: 1250344595
# Data Fetched for: 1245317002
# Data Fetched for: 1236777307
# Data Fetched for: 1217932516
# Data Fetched for: 1227658311
# Data Fetched for: 1237335760
# Data Fetched for: 1211235525
# Data Fetched for: 1236795881
# Data Fetched for: 1241904410
# Data Fetched for: 1243474576
# Data Fetched for: 1101186643
# Data Fetched for: 1248790402
# Data Fetched for: 1187122509
# Data Fetched for: 1177150880
# Data Fetched for: 1181274805
# Data Fetched for: 1188858837
# Data Fetched for: 1194947033
# Data Fetched for: 1165935460
# Data Fetched for: 1224650590
# Data Fetched for: 1231273948
# Data Fetched for: 1240877830
# Data Fetched for: 1139020686
# Data Fetched for: 1196782670
# Data Fetched for: 1188858797
# Data Fetched for: 1240877157
# Data Fetched for: 1188339738
# Data Fetched for: 1188917017
# Data Fetched for: 1108677667
# Data Fetched for: 1177650476
# Data Fetched for: 1219061952
# Data Fetched for: 1188339825
# Data Fetched for: 1115090605
# Data Fetched for: 1241452397
# Data Fetched for: 1186807529
# Data Fetched for: 1220964955
# Data Fetched for: 1227770299
# Data Fetched for: 1099231025
# Data Fetched for: 1193864167
# Data Fetched for: 1177650766
# Data Fetched for: 1203177077
# Data Fetched for: 1236924018
# Data Fetched for: 1226314813
# Data Fetched for: 1151370568
# Data Fetched for: 1087648145
# Data Fetched for: 1231942275
# Data Fetched for: 1210082543
# Data Fetched for: 1245373592
# Data Fetched for: 1216156762
# Data Fetched for: 1189278863
# Data Fetched for: 1177347217
# Data Fetched for: 1144174107
# Data Fetched for: 1210083613
# Data Fetched for: 1210083144
# Data Fetched for: 1169933380
# Data Fetched for: 1245373600
# Data Fetched for: 1250704546
# Data Fetched for: 1036478390
# Data Fetched for: 1227269939
# Data Fetched for: 1234386190
# Data Fetched for: 1210189937
# Data Fetched for: 1245412082
# Data Fetched for: 1221126119
# Data Fetched for: 1207433410
# Data Fetched for: 1250357483
# Data Fetched for: 1203399746
# Data Fetched for: 1246524261
# Data Fetched for: 1227561394
# Data Fetched for: 1250281251
# Data Fetched for: 1245373615
# Data Fetched for: 1240728343
# Data Fetched for: 1239820808
# Data Fetched for: 1205964987
# Data Fetched for: 1245372940
# Data Fetched for: 1250134288
# Data Fetched for: 1169934161
# Data Fetched for: 1245373645
# Data Fetched for: 1065794809
# Data Fetched for: 1140270731
# Data Fetched for: 1197273116
# Data Fetched for: 1245373470
# Data Fetched for: 1169933560
# Data Fetched for: 1248165000
# Data Fetched for: 1245372381
# Data Fetched for: 1210083781
# Data Fetched for: 1245373652
# Data Fetched for: 1087057198
# Data Fetched for: 1235897720
# Data Fetched for: 1147278693
# Data Fetched for: 1222232537
# Data Fetched for: 1210083818
# Data Fetched for: 1219791322
# Data Fetched for: 1177185207
# Data Fetched for: 1214544169
# Data Fetched for: 1245373664
# Data Fetched for: 987791661
# Data Fetched for: 1239004774
# Data Fetched for: 1227692854
# Data Fetched for: 1219791544
# Data Fetched for: 1245372417
# Data Fetched for: 1245373365
# Data Fetched for: 1245373050
# Data Fetched for: 1245618789
# Data Fetched for: 1238454181
# Data Fetched for: 1234388263
# Data Fetched for: 1170350688
# Data Fetched for: 1242193633
# Data Fetched for: 1239526756
# Data Fetched for: 1245373670
# Data Fetched for: 1142166678
# Data Fetched for: 1243165916
# Data Fetched for: 1192257938
# Data Fetched for: 1250459738
# Data Fetched for: 1250853841
# Data Fetched for: 1220263916
# Data Fetched for: 1207585856
# Data Fetched for: 1227694880
# Data Fetched for: 1244607980
# Data Fetched for: 1226287594
# Data Fetched for: 1247008320
# Data Fetched for: 1249889245
# Data Fetched for: 1172072408
# Data Fetched for: 1059652996
# Data Fetched for: 1235862392
# Data Fetched for: 1231164333
# Data Fetched for: 1218269209
# Data Fetched for: 1193500276
# Data Fetched for: 1176698590
# Data Fetched for: 1233102698
# Data Fetched for: 1227287425
# Data Fetched for: 1243757340
# Data Fetched for: 1227751790
# Data Fetched for: 1242000913
# Data Fetched for: 1217047991
# Data Fetched for: 1229174400
# Data Fetched for: 1243810904
# Data Fetched for: 1243810911
# Data Fetched for: 1243810923
# Data Fetched for: 1250510333
# Data Fetched for: 1234647985
# Data Fetched for: 1246668602
# Data Fetched for: 1210437333
# Data Fetched for: 1243810993
# Data Fetched for: 1096672232
# Data Fetched for: 1220226778
# Data Fetched for: 1171497670
# Data Fetched for: 1243811022
# Data Fetched for: 1243811027
# Data Fetched for: 1220843919
# Data Fetched for: 1243811051
# Data Fetched for: 1079121769
# Data Fetched for: 1244202380
# Data Fetched for: 1243811080
# Data Fetched for: 1194560189
# Data Fetched for: 1174776111
# Data Fetched for: 1221932398
# Data Fetched for: 1243811102
# Data Fetched for: 1243811136
# Data Fetched for: 1059565834
# Data Fetched for: 1243808497
# Data Fetched for: 1178861440
# Data Fetched for: 1243811146
# Data Fetched for: 1157572449
# Data Fetched for: 1171902721
# Data Fetched for: 1178094497
# Data Fetched for: 1243811158
# Data Fetched for: 1250884183
# Data Fetched for: 1249720857
# Data Fetched for: 1130454039
# Data Fetched for: 1241219287
# Data Fetched for: 1246435409
# Data Fetched for: 1249317685
# Data Fetched for: 1250931149
# Data Fetched for: 1229939964
# Data Fetched for: 1234063279
# Data Fetched for: 1243540290
# Data Fetched for: 1223788177
# Data Fetched for: 1041211681
# Data Fetched for: 1102345166
# Data Fetched for: 1009662257
# Data Fetched for: 1221349803
# Data Fetched for: 1108440685
# Data Fetched for: 1231186334
# Data Fetched for: 1249031959
# Data Fetched for: 1214426931
# Data Fetched for: 1219533774
# Data Fetched for: 1177650482
# Data Fetched for: 1240148045
# Data Fetched for: 1230583945
# Data Fetched for: 1226331859
# Data Fetched for: 1217696496
# Data Fetched for: 1017007525
# Data Fetched for: 1250196607
# Data Fetched for: 1108720863
# Data Fetched for: 1250160956
# Data Fetched for: 1225861548
# Data Fetched for: 1240147077
# Data Fetched for: 1177650598
# Data Fetched for: 1151361877
# Data Fetched for: 1251090687
# Data Fetched for: 1152439979
# Data Fetched for: 1227015746
# Data Fetched for: 1240137941
# Data Fetched for: 1098278415
# Data Fetched for: 1177650613
# Data Fetched for: 1146536611
# Data Fetched for: 1180554993
# Data Fetched for: 1242817206
# Data Fetched for: 1148553193
# Data Fetched for: 1199699881
# Data Fetched for: 1225866384
# Data Fetched for: 1226983598
# Data Fetched for: 1239668367
# Data Fetched for: 1235834775
# Data Fetched for: 1216083405
# Data Fetched for: 1249443443
# Data Fetched for: 1191590141
# Data Fetched for: 1225864918
# Data Fetched for: 1177459663
# Data Fetched for: 1101613548
# Data Fetched for: 1213485215
# Data Fetched for: 1216635216
# Data Fetched for: 1213485569
# Data Fetched for: 1248397829
# Data Fetched for: 1217196175
# Data Fetched for: 1211998269
# Data Fetched for: 1242454262
# Data Fetched for: 1221994311
# Data Fetched for: 1240973609
# Data Fetched for: 1239810898
# Data Fetched for: 1159473113
# Data Fetched for: 1140307699
# Data Fetched for: 1242127344
# Data Fetched for: 1226461295
# Data Fetched for: 1246969392
# Data Fetched for: 1224144854
# Data Fetched for: 1251051521
# Data Fetched for: 1229277170
# Data Fetched for: 1243871975
# Data Fetched for: 1195939436
# Data Fetched for: 1227146224
# Data Fetched for: 1191501257
# Data Fetched for: 1175430342
# Data Fetched for: 1236321102
# Data Fetched for: 1247480258
# Data Fetched for: 1185921742
# Data Fetched for: 1246170190
# Data Fetched for: 1162338564
# Data Fetched for: 1108077983
# Data Fetched for: 1207731827
# Data Fetched for: 872461806
# Data Fetched for: 1231975933
# Data Fetched for: 1179344861
# Data Fetched for: 872513852
# Data Fetched for: 1144389013
# Data Fetched for: 1085015143
# Data Fetched for: 1193126229
# Data Fetched for: 1250337903
# Data Fetched for: 1235451008
# Data Fetched for: 1232887754
# Data Fetched for: 1240166319
# Data Fetched for: 1247622508
# Data Fetched for: 1241145448
# Data Fetched for: 1246582918
# Data Fetched for: 1246583396
# Data Fetched for: 1216583569
# Data Fetched for: 1246582150
# Data Fetched for: 1246582796
# Data Fetched for: 1246583602
# Data Fetched for: 1233099485
# Data Fetched for: 1246583605
# Data Fetched for: 1236685196
# Data Fetched for: 1209556113
# Data Fetched for: 1246583619
# Data Fetched for: 1246582974
# Data Fetched for: 1238013543
# Data Fetched for: 1220158605
# Data Fetched for: 1241138604
# Data Fetched for: 1241826912
# Data Fetched for: 1210732533
# Data Fetched for: 1232905225
# Data Fetched for: 1241145426
# Data Fetched for: 1216869009
# Data Fetched for: 1218197818
# Data Fetched for: 1232904571
# Data Fetched for: 1240072329
# Data Fetched for: 1246581836
# Data Fetched for: 1225804893
# Data Fetched for: 1234717906
# Data Fetched for: 1224512179
# Data Fetched for: 1197442605
# Data Fetched for: 1246581884
# Data Fetched for: 1233100674
# Data Fetched for: 1240166225
# Data Fetched for: 1246581897
# Data Fetched for: 1246582371
# Data Fetched for: 1237244682
# Data Fetched for: 1233081384
# Data Fetched for: 1246581910
# Data Fetched for: 1246276668
# Data Fetched for: 1246286451
# Data Fetched for: 1246582387
# Data Fetched for: 1246582394
# Data Fetched for: 1230256788
# Data Fetched for: 1226080617
# Data Fetched for: 1246584115
# Data Fetched for: 1246582411
# Data Fetched for: 1245058533
# Data Fetched for: 1233099801
# Data Fetched for: 1235451028
# Data Fetched for: 1247033778
# Data Fetched for: 1246583701
# Data Fetched for: 1193587402
# Data Fetched for: 1246583715
# Data Fetched for: 1240166459
# Data Fetched for: 1241138610
# Data Fetched for: 1245997885
# Data Fetched for: 1037723664
# Data Fetched for: 1240382229
# Data Fetched for: 1240083184
# Data Fetched for: 1222977958
# Data Fetched for: 1117001263
# Data Fetched for: 1182205038
# Data Fetched for: 1222254128
# Data Fetched for: 1230177446
# Data Fetched for: 1250403358
# Data Fetched for: 1229515337
# Data Fetched for: 1183319623
# Data Fetched for: 1247579845
# Data Fetched for: 1243521667
# Data Fetched for: 1234882199
# Data Fetched for: 1112864760
# Data Fetched for: 1213106474
# Data Fetched for: 1243512125
# Data Fetched for: 1240223372
# Data Fetched for: 1245229750
# Data Fetched for: 1245229754
# Data Fetched for: 1245234693
# Data Fetched for: 1246254621
# Data Fetched for: 1245236501
# Data Fetched for: 1215952443
# Data Fetched for: 1245229792
# Data Fetched for: 1145659050
# Data Fetched for: 1245233085
# Data Fetched for: 1245229806
# Data Fetched for: 1245229831
# Data Fetched for: 1216025693
# Data Fetched for: 1246254674
# Data Fetched for: 1245233092
# Data Fetched for: 1245229841
# Data Fetched for: 1246254698
# Data Fetched for: 1177713760
# Data Fetched for: 1245229857
# Data Fetched for: 1170558228
# Data Fetched for: 1245235873
# Data Fetched for: 1245229862
# Data Fetched for: 1245236200
# Data Fetched for: 1245233259
# Data Fetched for: 1230172715
# Data Fetched for: 1246255193
# Data Fetched for: 1245229882
# Data Fetched for: 1240176611
# Data Fetched for: 1245233082
# Data Fetched for: 1245229888
# Data Fetched for: 1245236372
# Data Fetched for: 1245233277
# Data Fetched for: 1245234381
# Data Fetched for: 1250271191
# Data Fetched for: 1248682870
# Data Fetched for: 1184527110
# Data Fetched for: 1069225684
# Data Fetched for: 1240223425
# Data Fetched for: 1199118382
# Data Fetched for: 1250547066
# Data Fetched for: 1246254780
# Data Fetched for: 1246254788
# Data Fetched for: 1246255201
# Data Fetched for: 1245235971
# Data Fetched for: 1236266474
# Data Fetched for: 1222201469
# Data Fetched for: 1245235175
# Data Fetched for: 1185742882
# Data Fetched for: 1245235975
# Data Fetched for: 1028093034
# Data Fetched for: 1164689541
# Data Fetched for: 1245236941
# Data Fetched for: 1246254840
# Data Fetched for: 1173626216
# Data Fetched for: 1245233340
# Data Fetched for: 1245235981
# Data Fetched for: 1249030421
# Data Fetched for: 1245235291
# Data Fetched for: 1015926064
# Data Fetched for: 1216456187
# Data Fetched for: 1227553742
# Data Fetched for: 1244437288
# Data Fetched for: 1220326566
# Data Fetched for: 1246255224
# Data Fetched for: 1221854205
# Data Fetched for: 1247090171
# Data Fetched for: 1245238707
# Data Fetched for: 1161329015
# Data Fetched for: 1213699898
# Data Fetched for: 1228551844
# Data Fetched for: 1161329073
# Data Fetched for: 1246254972
# Data Fetched for: 1245235067
# Data Fetched for: 1245233403
# Data Fetched for: 1245706441
# Data Fetched for: 1245234958
# Data Fetched for: 1240167842
# Data Fetched for: 1245232426
# Data Fetched for: 1245477212
# Data Fetched for: 1249127568
# Data Fetched for: 1243241622
# Data Fetched for: 1246290098
# Data Fetched for: 1247355339
# Data Fetched for: 1247354060
# Data Fetched for: 1221994066
# Data Fetched for: 1175970303
# Data Fetched for: 1196223038
# Data Fetched for: 1190414185
# Data Fetched for: 1247353598
# Data Fetched for: 1186382326
# Data Fetched for: 1131245612
# Data Fetched for: 1054672013
# Data Fetched for: 1136343767
# Data Fetched for: 1226333799
# Data Fetched for: 1197939649
# Data Fetched for: 1247384439
# Data Fetched for: 1159714281
# Data Fetched for: 1236977988
# Data Fetched for: 1043132737
# Data Fetched for: 1136366247
# Data Fetched for: 1247355431
# Data Fetched for: 1242492711
# Data Fetched for: 1154376625
# Data Fetched for: 1248517558
# Data Fetched for: 1234167840
# Data Fetched for: 1246299510
# Data Fetched for: 1135246225
# Data Fetched for: 1246821116
# Data Fetched for: 1146697785
# Data Fetched for: 826516065
# Data Fetched for: 1223558585
# Data Fetched for: 1177650425
# Data Fetched for: 1124446209
# Data Fetched for: 1146540238
# Data Fetched for: 1141825144
# Data Fetched for: 1152185896
# Data Fetched for: 1146545045
# Data Fetched for: 1112682469
# Data Fetched for: 1156202898
# Data Fetched for: 1177650547
# Data Fetched for: 1247163377
# Data Fetched for: 1227758610
# Data Fetched for: 1146540347
# Data Fetched for: 976591922
# Data Fetched for: 1221206415
# Data Fetched for: 1209020061
# Data Fetched for: 1146545877
# Data Fetched for: 1146539782
# Data Fetched for: 1235566637
# Data Fetched for: 1221600122
# Data Fetched for: 1106155664
# Data Fetched for: 1127419766
# Data Fetched for: 1161287091
# Data Fetched for: 1240112055
# Data Fetched for: 1209006607
# Data Fetched for: 1053664162
# Data Fetched for: 1178358315
# Data Fetched for: 1246747483
# Data Fetched for: 1176623737
# Data Fetched for: 1212136112
# Data Fetched for: 1180021058
# Data Fetched for: 1156020993
# Data Fetched for: 1063619600
# Data Fetched for: 1053664863
# Data Fetched for: 1175866265
# Data Fetched for: 1053665874
# Data Fetched for: 1158543582
# Data Fetched for: 1207022384
# Data Fetched for: 1112278142
# Data Fetched for: 1178367789
# Data Fetched for: 1249521619
# Data Fetched for: 1002487446
# Data Fetched for: 1176430546
# Data Fetched for: 1237115839
# Data Fetched for: 1248824563
# Data Fetched for: 1243865684
# Data Fetched for: 1249285899
# Data Fetched for: 1053664236
# Data Fetched for: 1211274287
# Data Fetched for: 1244086359
# Data Fetched for: 1233422388
# Data Fetched for: 1147505613
# Data Fetched for: 1245170396
# Data Fetched for: 1188621879
# Data Fetched for: 1221364267
# Data Fetched for: 1125303194
# Data Fetched for: 1058408130
# Data Fetched for: 1221204219
# Data Fetched for: 1158533179
# Data Fetched for: 1230882624
# Data Fetched for: 1234382434
# Data Fetched for: 1247424323
# Data Fetched for: 1207925066
# Data Fetched for: 1221395785
# Data Fetched for: 1249280194
# Data Fetched for: 1220065911
# Data Fetched for: 1247976741
# Data Fetched for: 1244131957
# Data Fetched for: 1087110784
# Data Fetched for: 1194658548
# Data Fetched for: 1169619132
# Data Fetched for: 1053666295
# Data Fetched for: 1226227200
# Data Fetched for: 1092371503
# Data Fetched for: 1226028337
# Data Fetched for: 1220759536
# Data Fetched for: 1003975565
# Data Fetched for: 1222311219
# Data Fetched for: 1222118361
# ...
# Data Fetched for: 1246514462
# Data Fetched for: 1189113633
# Data Fetched for: 1245092447
# Data Fetched for: 1137678089
# Data Fetched for: 1226154964
# Data Fetched for: 1248500772
# Data Fetched for: 1243051498
# Data Fetched for: 1249921858
# Data Fetched for: 1248547868
# Data Fetched for: 1191575496
# Data Fetched for: 1239972537
# Data Fetched for: 1237258272
# Data Fetched for: 1165387534
# Data Fetched for: 1226174343
# Data Fetched for: 1150862730
# Data Fetched for: 1222221753
# Data Fetched for: 1069865479
# Data Fetched for: 1225418442
# Data Fetched for: 1093387022
# Data Fetched for: 1251055361
# Data Fetched for: 1246337794
# Data Fetched for: 1248790750
# Data Fetched for: 1226188291
# Data Fetched for: 1068252041
# Data Fetched for: 1226116184
# Data Fetched for: 1244979496
# Data Fetched for: 1154908966
# Data Fetched for: 1239894377
# Data Fetched for: 1065378015
# Data Fetched for: 1220777049
# Data Fetched for: 1228300948
# Data Fetched for: 1247120291
# Data Fetched for: 1244334799
# Data Fetched for: 1234065530
# Data Fetched for: 1143929714
# Data Fetched for: 1241312980
# Data Fetched for: 1230379647
# Data Fetched for: 1161356025
# Data Fetched for: 1242565581
# Data Fetched for: 1188787560
# Data Fetched for: 1215567546
# Data Fetched for: 1222073597
# Data Fetched for: 1226779277
# Data Fetched for: 1233135330
# Data Fetched for: 1231353179
# Data Fetched for: 1241574430
# Data Fetched for: 1226204581
# Data Fetched for: 1240898056
# Data Fetched for: 1226205451
# Data Fetched for: 1222045087
# Data Fetched for: 1239513332
# Data Fetched for: 1240634849
# Data Fetched for: 1245358961
# Data Fetched for: 1226211497
# Data Fetched for: 1223428429
# Data Fetched for: 1173064538
# Data Fetched for: 1242256661
# Data Fetched for: 1242565618
# Data Fetched for: 1240981396
# Data Fetched for: 1240259800
# Data Fetched for: 1240891443
# Data Fetched for: 1227931073
# Data Fetched for: 1240004651
# Data Fetched for: 1240004707
# Data Fetched for: 1231553705
# Data Fetched for: 1237840723
# Data Fetched for: 1104322145
# Data Fetched for: 1240776519
# Data Fetched for: 1240804152
# Data Fetched for: 1242962207
# Data Fetched for: 1144503312
# Data Fetched for: 1221143754
# Data Fetched for: 1210860457
# Data Fetched for: 1231553871
# Data Fetched for: 1234101505
# Data Fetched for: 1001280832
# Data Fetched for: 971361950
# Data Fetched for: 1235919925
# Data Fetched for: 1158805969
# Data Fetched for: 1243650424
# Data Fetched for: 1228470873
# Data Fetched for: 1249590782
# Data Fetched for: 1250926280
# Data Fetched for: 1237391547
# Data Fetched for: 1236241537
# Data Fetched for: 1230350617
# Data Fetched for: 1235511227
# Data Fetched for: 1146695614
# Data Fetched for: 1226369269
# Data Fetched for: 1233839679
# Data Fetched for: 1238513656
# Data Fetched for: 1222297199
# Data Fetched for: 1130505690
# Data Fetched for: 1228879346
# Data Fetched for: 1227609154
# Data Fetched for: 1243240587
# Data Fetched for: 1244017494
# Data Fetched for: 1226378603
# Data Fetched for: 1062661561
# Data Fetched for: 1226380770
# Data Fetched for: 1187316535
# Data Fetched for: 1244174684
# Data Fetched for: 1103370473
# Data Fetched for: 1232348830
# Data Fetched for: 1246159519
# Data Fetched for: 1232322281
# Data Fetched for: 1083450519
# Data Fetched for: 1225731455
# Data Fetched for: 1119564390
# Data Fetched for: 1205444933
# Data Fetched for: 1122203734
# Data Fetched for: 1226111002
# Data Fetched for: 1238412906
# Data Fetched for: 1177420715
# Data Fetched for: 1118204026
# Data Fetched for: 1204621612
# Data Fetched for: 1164966747
# Data Fetched for: 1221278854
# Data Fetched for: 1216081687
# Data Fetched for: 1161584075
# Data Fetched for: 1156045704
# Data Fetched for: 1118204107
# Data Fetched for: 1118203952
# Data Fetched for: 1163124965
# Data Fetched for: 1232322174
# Data Fetched for: 1243379211
# Data Fetched for: 1243618134
# Data Fetched for: 1247683483
# Data Fetched for: 1248921819
# Data Fetched for: 1173589571
# Data Fetched for: 1247604735
# Data Fetched for: 1225990254
# Data Fetched for: 1242765206
# Data Fetched for: 1157530218
# Data Fetched for: 1226946571
# Data Fetched for: 1247440581
# Data Fetched for: 1240228353
# Data Fetched for: 1220371513
# Data Fetched for: 1179418320
# Data Fetched for: 1211043784
# Data Fetched for: 1246982301
# Data Fetched for: 1118204096
# Data Fetched for: 1188372971
# Data Fetched for: 1244105942
# Data Fetched for: 1234384469
# Data Fetched for: 1194465925
# Data Fetched for: 1158045142
# Data Fetched for: 1232437700
# Data Fetched for: 1246424186
# Data Fetched for: 1223108932
# Data Fetched for: 1231258246
# Data Fetched for: 1249587277
# Data Fetched for: 1118204132
# Data Fetched for: 1118203914
# Data Fetched for: 1189128481
# Data Fetched for: 1242252016
# Data Fetched for: 1133912529
# Data Fetched for: 1016735357
# Data Fetched for: 1228262014
# Data Fetched for: 1231096508
# Data Fetched for: 1228261278
# Data Fetched for: 1242284183
# Data Fetched for: 1227213476
# Data Fetched for: 1231590847
# Data Fetched for: 1222957267
# Data Fetched for: 1228325819
# Data Fetched for: 1228345888
# Data Fetched for: 1145140846
# Data Fetched for: 1230133462
# Data Fetched for: 1195917199
# Data Fetched for: 1015536139
# Data Fetched for: 1102909542
# Data Fetched for: 1177403953
# Data Fetched for: 1220742353
# Data Fetched for: 1188598687
# Data Fetched for: 1217472460
# Data Fetched for: 1244829604
# Data Fetched for: 1249577124
# Data Fetched for: 1241053119
# Data Fetched for: 1235527107
# Data Fetched for: 1225818991
# Data Fetched for: 1238485439
# Data Fetched for: 1180481554
# Data Fetched for: 1228343915
# Data Fetched for: 1220669085
# Data Fetched for: 1025501033
# Data Fetched for: 1189714237
# Data Fetched for: 1179963758
# Data Fetched for: 1241621063
# Data Fetched for: 1242679828
# Data Fetched for: 1178323740
# Data Fetched for: 1157234813
# Data Fetched for: 1171242393
# Data Fetched for: 1234308934
# Data Fetched for: 1138773088
# Data Fetched for: 1214405631
# Data Fetched for: 1231187957
# Data Fetched for: 1214352187
# Data Fetched for: 1226298707
# Data Fetched for: 1243645294
# Data Fetched for: 1157228808
# Data Fetched for: 1063277893
# Data Fetched for: 1231993438
# Data Fetched for: 1169321796
# Data Fetched for: 1219849021
# Data Fetched for: 1233177790
# Data Fetched for: 1225689289
# Data Fetched for: 1231545434
# Data Fetched for: 1187822681
# Data Fetched for: 1172887309
# Data Fetched for: 1230417967
# Data Fetched for: 1240195055
# Data Fetched for: 1186381012
# Data Fetched for: 1226483955
# Data Fetched for: 1230984048
# Data Fetched for: 1178513406
# Data Fetched for: 1213635496
# Data Fetched for: 1190559256
# Data Fetched for: 1177650762
# Data Fetched for: 1246469917
# Data Fetched for: 1129731289
# Data Fetched for: 1231770164
# Data Fetched for: 1242807439
# Data Fetched for: 1245162145
# Data Fetched for: 1225354614
# Data Fetched for: 1242807387
# Data Fetched for: 1215776481
# Data Fetched for: 1233268491
# Data Fetched for: 1170739829
# Data Fetched for: 1242176652
# Data Fetched for: 1211442079
# Data Fetched for: 1190122265
# Data Fetched for: 1189968275
# Data Fetched for: 1222160201
# Data Fetched for: 1219573961
# Data Fetched for: 1156355955
# Data Fetched for: 1224213889
# Data Fetched for: 1247861822
# Data Fetched for: 1246159936
# Data Fetched for: 1248663780
# Data Fetched for: 1250252849
# Data Fetched for: 1221928174
# Data Fetched for: 1242253141
# Data Fetched for: 1215401761
# Data Fetched for: 1242496812
# Data Fetched for: 1127705961
# Data Fetched for: 1248295740
# Data Fetched for: 1241151320
# Data Fetched for: 1105537507
# Data Fetched for: 1144570454
# Data Fetched for: 1071832914
# Data Fetched for: 1176875041
# Data Fetched for: 1161799415
# Data Fetched for: 1246577456
# Data Fetched for: 1206969587
# Data Fetched for: 1189706771
# Data Fetched for: 1244197773
# Data Fetched for: 1190558665
# Data Fetched for: 1099843841
# Data Fetched for: 1244094860
# Data Fetched for: 1173706360
# Data Fetched for: 1234699497
# Data Fetched for: 1232824556
# Data Fetched for: 1244840590
# Data Fetched for: 1248975727
# Data Fetched for: 1244094728
# Data Fetched for: 1244094811
# Data Fetched for: 1243382687
# Data Fetched for: 1251097963
# Data Fetched for: 1221102733
# Data Fetched for: 1224935116
# Data Fetched for: 1227213476
# Data Fetched for: 1184919604
# Data Fetched for: 1173755289
# Data Fetched for: 1250417536
# Data Fetched for: 1219318782
# Data Fetched for: 1196013744
# Data Fetched for: 1243219659
# Data Fetched for: 1247545730
# Data Fetched for: 1227062098
# Data Fetched for: 1122819804
# Data Fetched for: 1104275868
# Data Fetched for: 1250265293
# Data Fetched for: 1225451471
# Data Fetched for: 1183485100
# Data Fetched for: 1127474919
# Data Fetched for: 1093553119
# Data Fetched for: 1241979774
# Data Fetched for: 1029640359
# Data Fetched for: 1225123124
# Data Fetched for: 1226148197
# Data Fetched for: 1226127936
# Data Fetched for: 1217589862
# Data Fetched for: 1210205888
# Data Fetched for: 1030716598
# Data Fetched for: 1226128145
# Data Fetched for: 1236501380
# Data Fetched for: 1189139711
# Data Fetched for: 1212561738
# Data Fetched for: 1218731042
# Data Fetched for: 1221961669
# Data Fetched for: 1198918159
# Data Fetched for: 1181454060
# Data Fetched for: 1222150298
# Data Fetched for: 1245851485
# Data Fetched for: 1177400698
# Data Fetched for: 1120590347
# Data Fetched for: 1217438745
# Data Fetched for: 1247456996
# Data Fetched for: 1194939369
# Data Fetched for: 1226809980
# Data Fetched for: 1221058943
# Data Fetched for: 1120590142
# Data Fetched for: 1171333227
# Data Fetched for: 1227415124
# Data Fetched for: 1214416146
# Data Fetched for: 1147889438
# Data Fetched for: 1171871582
# Data Fetched for: 1051406176
# Data Fetched for: 1017820647
# Data Fetched for: 1226641724
# Data Fetched for: 1228990168
# Data Fetched for: 1153429385
# Data Fetched for: 1249029861
# Data Fetched for: 1248580671
# Data Fetched for: 1248262096
# Data Fetched for: 1163342472
# Data Fetched for: 1111996748
# Data Fetched for: 1171540302
# Data Fetched for: 1187741965
# Data Fetched for: 1237567100
# Data Fetched for: 1233767745
# Data Fetched for: 898985019
# Data Fetched for: 1081132162
# Data Fetched for: 1204304297
# Data Fetched for: 942771137
# Data Fetched for: 1081132167
# Data Fetched for: 1226650554
# Data Fetched for: 1246289515
# Data Fetched for: 1228957061
# Data Fetched for: 1249056066
# Data Fetched for: 1081132142
# Data Fetched for: 1089406791
# Data Fetched for: 1249071898
# Data Fetched for: 1248033733
# Data Fetched for: 1181058820
# Data Fetched for: 1246089316
# Data Fetched for: 1164628746
# Data Fetched for: 1089407038
# Data Fetched for: 935489367
# Data Fetched for: 1230614310
# Data Fetched for: 1182731594
# Data Fetched for: 1218562138
# Data Fetched for: 998207348
# Data Fetched for: 1146539675
# Data Fetched for: 1045602198
# Data Fetched for: 1249914090
# Data Fetched for: 1249314157
# Data Fetched for: 1180244988
# Data Fetched for: 1218413935
# Data Fetched for: 1218499041
# Data Fetched for: 1121161249
# Data Fetched for: 1212248638
# Data Fetched for: 1218041682
# Data Fetched for: 1194943342
# Data Fetched for: 1008352289
# Data Fetched for: 1193643268
# Data Fetched for: 1192211234
# Data Fetched for: 1213588389
# Data Fetched for: 1175892177
# Data Fetched for: 1220817543
# Data Fetched for: 1213680658
# Data Fetched for: 1187030749
# Data Fetched for: 1153429446
# Data Fetched for: 1237546774
# Data Fetched for: 1238401101
# Data Fetched for: 1232095812
# Data Fetched for: 1249079014
# Data Fetched for: 1244232481
# Data Fetched for: 1230951133
# Data Fetched for: 1241440166
# Data Fetched for: 1242619180
# Data Fetched for: 1245825172
# Data Fetched for: 1251033410
# Data Fetched for: 1232500619
# Data Fetched for: 1238049866
# Data Fetched for: 1232500347
# Data Fetched for: 1250733082
# Data Fetched for: 1244482122
# Data Fetched for: 1240433792
# Data Fetched for: 1245214535
# Data Fetched for: 1235596015
# Data Fetched for: 1232500872
# Data Fetched for: 1241961199
# Data Fetched for: 1246694309
# Data Fetched for: 1246386346
# Data Fetched for: 1244286661
# Data Fetched for: 1232091907
# Data Fetched for: 1245818465
# Data Fetched for: 1246349324
# Data Fetched for: 1246672381
# Data Fetched for: 1236240854
# Data Fetched for: 1249874760
# Data Fetched for: 1241441616
# Data Fetched for: 1235673745
# Data Fetched for: 1242240347
# Data Fetched for: 1249542355
# Data Fetched for: 1241442047
# Data Fetched for: 1232660773
# Data Fetched for: 1238540411
# Data Fetched for: 1240917492
# Data Fetched for: 1239236334
# Data Fetched for: 1244248047
# Data Fetched for: 1243274616
# Data Fetched for: 1238047054
# Data Fetched for: 1240428350
# Data Fetched for: 1241309246
# Data Fetched for: 1238047760
# Data Fetched for: 1232660835
# Data Fetched for: 1232659904
# Data Fetched for: 1241560614
# Data Fetched for: 1237816427
# Data Fetched for: 1236727642
# Data Fetched for: 1230949310
# Data Fetched for: 1232658136
# Data Fetched for: 1241559866
# Data Fetched for: 1249552533
# Data Fetched for: 1245989282
# Data Fetched for: 1247449899
# Data Fetched for: 1248190926
# Data Fetched for: 1232659961
# Data Fetched for: 1240427204
# Data Fetched for: 1244007593
# Data Fetched for: 1246270275
# Data Fetched for: 1239167371
# Data Fetched for: 1245717814
# Data Fetched for: 1238076710
# Data Fetched for: 1249683539
# Data Fetched for: 1232663282
# Data Fetched for: 1250597297
# Data Fetched for: 1235989081
# Data Fetched for: 1240256587
# Data Fetched for: 1244283795
# Data Fetched for: 1230954821
# Data Fetched for: 1232500927
# Data Fetched for: 1232662322
# Data Fetched for: 1243128389
# Data Fetched for: 1241004899
# Data Fetched for: 1232661745
# Data Fetched for: 1244788344
# Data Fetched for: 1230949238
# Data Fetched for: 1238063699
# Data Fetched for: 1250770904
# Data Fetched for: 1250228285
# Data Fetched for: 1241591050
# Data Fetched for: 1248644798
# Data Fetched for: 1243484978
# Data Fetched for: 1248295135
# Data Fetched for: 1247962023
# Data Fetched for: 1232661856
# Data Fetched for: 1232662862
# Data Fetched for: 1230951586
# Data Fetched for: 1230950406
# Data Fetched for: 1230950894
# Data Fetched for: 1232662468
# Data Fetched for: 1240429624
# Data Fetched for: 1230863495
# Data Fetched for: 1249860352
# Data Fetched for: 1232500861
# Data Fetched for: 1244286802
# Data Fetched for: 1230872362
# Data Fetched for: 1239541448
# Data Fetched for: 1246829948
# Data Fetched for: 1237817149
# Data Fetched for: 1250244997
# Data Fetched for: 1249860212
# Data Fetched for: 1239218290
# Data Fetched for: 1245355032
# Data Fetched for: 1232662973
# Data Fetched for: 1242025964
# Data Fetched for: 1236472677
# Data Fetched for: 1239275784
# Data Fetched for: 1250921862
# Data Fetched for: 1242235717
# Data Fetched for: 1232663181
# Data Fetched for: 1239207188
# Data Fetched for: 1242975657
# Data Fetched for: 1238082218
# Data Fetched for: 1232321936
# Data Fetched for: 1248994009
# Data Fetched for: 1232659274
# Data Fetched for: 1245508040
# Data Fetched for: 1232095602
# Data Fetched for: 1230951033
# Data Fetched for: 1239231148
# Data Fetched for: 1241441147
# Data Fetched for: 1241477061
# Data Fetched for: 1247361412
# Data Fetched for: 1244482185
# Data Fetched for: 1249868085
# Data Fetched for: 1241562397
# Data Fetched for: 1241589874
# Data Fetched for: 1237922764
# Data Fetched for: 1238710746
# Data Fetched for: 1232662873
# Data Fetched for: 1238359601
# Data Fetched for: 1241441440
# Data Fetched for: 1238063554
# Data Fetched for: 1237817306
# Data Fetched for: 1238407722
# Data Fetched for: 1242318759
# Data Fetched for: 1248598184
# Data Fetched for: 1232659887
# Data Fetched for: 1230949473
# Data Fetched for: 1246494673
# Data Fetched for: 1241967765
# Data Fetched for: 1250771020
# Data Fetched for: 1242674101
# Data Fetched for: 1249322042
# Data Fetched for: 1232721658
# Data Fetched for: 1250235413
# Data Fetched for: 1232660538
# Data Fetched for: 1240519421
# Data Fetched for: 1245797987
# Data Fetched for: 1232991785
# Data Fetched for: 1244191166
# Data Fetched for: 1099307042
# Data Fetched for: 1250965801
# Data Fetched for: 1250965860
# Data Fetched for: 1243385610
# Data Fetched for: 1229864427
# Data Fetched for: 1250965925
# Data Fetched for: 1229389001
# Data Fetched for: 1247255923
# Data Fetched for: 1230187180
# Data Fetched for: 1226762864
# Data Fetched for: 1233396798
# Data Fetched for: 1244191276
# Data Fetched for: 1220128786
# Data Fetched for: 1230186154
# Data Fetched for: 1245337842
# Data Fetched for: 1230187783
# Data Fetched for: 1248519130
# Data Fetched for: 1163823822
# Data Fetched for: 1209003568
# Data Fetched for: 1204553323
# Data Fetched for: 1182379636
# Data Fetched for: 1242263585
# Data Fetched for: 1250748962
# Data Fetched for: 1244191081
# Data Fetched for: 1211229924

# %% [markdown]
# ## Assigning Regions to Countries
#
# In this section, we process the **population dataset** to map each country to its respective region. The region information is present as uppercase entries in the 'Geography' column, which signifies the start of a new region. The countries that follow each region entry are assigned to that region.
#
# ### Steps:
# 1. **Identify Regions**:
#    - We identify all rows in the `population_df` where the 'Geography' entry is in all uppercase, indicating that these rows represent regions.
#
# 2. **Add a Region Column**:
#    - We create a new column `region` in `population_df` to store the region name for each country.
#
# 3. **Assign Regions to Countries**:
#    - We iterate through the dataset and, for each row, check whether it represents a region or a country:
#      - If the row represents a region, we set it as the current region.
#      - If the row represents a country, we assign the current region to that country.
#
# 4. **Remove Region Rows**:
#    - After assigning regions to all countries, we remove the rows corresponding to the region names, keeping only the country rows.
#
# 5. **Rename Columns**:
#    - The columns are renamed to `country`, `population`, and `region` for clarity.
#
# 6. **Save Transformed Data**:
#    - The final dataset with countries and their corresponding regions is saved as `country_population_with_region.csv` for future analysis.

# %%
# Identify the rows that represent regions (ALL CAPS entries in 'Geography')
regions = population_df[population_df['Geography'].str.isupper()].copy()

# Create an empty column for regions in the population_df
population_df['region'] = None

# Iterate over the regions and assign the corresponding region to countries
current_region = None
for index, row in population_df.iterrows():
    if row['Geography'].isupper():
        # If the row is a region, set it as the current region
        current_region = row['Geography']
    else:
        # If the row is a country, assign the current region
        population_df.at[index, 'region'] = current_region

# Remove the rows corresponding to regions and keep only the country rows
country_population_df = population_df[~population_df['Geography'].str.isupper()].copy()

# Rename the columns to 'country', 'population', and 'region'
country_population_df = country_population_df.rename(columns={'Geography': 'country', 'Population': 'population'})

# Display the transformed DataFrame
display(country_population_df.head())

# Save the final DataFrame to a CSV file for future use
country_population_df.to_csv('../data/country_population_with_region.csv', index=False)
# Out:
#    country  population           region
# 3  Algeria        46.8  NORTHERN AFRICA
# 4    Egypt       105.2  NORTHERN AFRICA
# 5    Libya         6.9  NORTHERN AFRICA
# 6  Morocco        37.0  NORTHERN AFRICA
# 7    Sudan        48.1  NORTHERN AFRICA
